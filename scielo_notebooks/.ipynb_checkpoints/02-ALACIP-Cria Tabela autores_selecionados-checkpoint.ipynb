# %%
local_dir = '/home/neilor/SCIELO_DADOS/alacip/'
connect_cmd = "dbname='scielo_db' user='neilor' host='localhost' password='n1f2c3n1'"
# %load_ext sql
# %sql postgresql://neilor:n1f2c3n1@/scielo_db
import psycopg2 as pg
# Out:
# /home/neilor/anaconda3/lib/python3.6/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated since IPython 4.0. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /home/neilor/anaconda3/lib/python3.6/site-packages/sql/magic.py:4: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   from IPython.utils.traitlets import Bool, Int, Unicode

# %%
query_create_table_autores_selecionados = """
drop table if exists alacip.autores_selecionados;
create table alacip.autores_selecionados
(
    artigo_scielo_id       varchar,
    autor_nome_completo    varchar,
    autor_nome_normal      varchar,
    autor_sexo             varchar,
    autor_instituicao      varchar,
    autor_cidade_instituicao    varchar,
    autor_pq varchar
);
"""
    
# %sql {query_create_table_autores_selecionados}


query_populate_autores_selecionados = """
insert into alacip.autores_selecionados 
(
artigo_scielo_id,
autor_nome_completo,
autor_instituicao,
autor_cidade_instituicao
)
select
    document_publishing_id_scielo     as    artigo_scielo_id,
    document_author                   as    autor_nome_completo,
    document_author_institution       as    autor_instituicao,
    document_author_affiliation_city  as    autor_cidade_instituicao
from
    documents_authors
where
    document_publishing_id_scielo 
    in (select scielo_id from alacip.artigos_selecionados)
order by
    autor_nome_completo,
    autor_instituicao,
    autor_cidade_instituicao
;
"""
    
# %sql {query_populate_autores_selecionados }
# Out:
# Done.
# Done.
# 17575 rows affected.
# []

# %%
conn = pg.connect(connect_cmd)
df_selec = pd.read_sql("select scielo_id from alacip.artigos_selecionados;",conn)
df_selec

# %%
query_documents = """
select
    document_publishing_id_scielo     as    scielo_id,
    document_author                   as    nome,
    document_author_institution       as    instituicao,
    document_author_affiliation_city  as    cidade_instituicao
from
    documents_authors;
"""

df_docs = pd.read_sql(query_documents, conn)
df_docs.merge(df_selec)
# Out:
#                      scielo_id                              nome  \
# 0      S0011-52581997000300007                    Fabiano Santos
# 1      S0011-52581997000300005           Flávio da Cunha Rezende
# 2      S0011-52581997000300006             Jairo Marconi Nicolau
# 3      S0011-52581997000300003     Maria Helena de Castro Santos
# 4      S0011-52581997000300008                     David Samuels
# 5      S0011-52581997000300004     Manoel Tibério Alves de Souza
# 6      S0011-52581998000100004  Breno Augusto Souto-Maior Fontes
# 7      S0011-52581998000100002           Cláudio Gonçalves Couto
# 8      S0011-52581998000100001                  Philippe Faucher
# 9      S0011-52581998000100005               Gian Mario Giuliani
# 10     S0011-52581998000100006                  H. B. Cavalcanti
# 11     S0011-52581998000100003                        Mario Fuks
# 12     S0011-52581997000200001         Adalberto Moreira Cardoso
# 13     S0011-52581997000200004                 Emerson Giumbelli
# 14     S0011-52581997000200002             Marcelo Gantus Jasmin
# 15     S0011-52581997000200006                       Mônica Herz
# 16     S0011-52581997000200003           José Murilo de Carvalho
# 17     S0011-52581997000200005         Renan Springer de Freitas
# 18     S0011-52581998000200004    José Alcides Figueiredo Santos
# 24     Universidade Estadual Paulista - Unesp -, Camp...
# 25               Associação Nacional de História - Anpuh
# 26                                                 UFPel
# 27                                                  None               None
# 28                        Universidade Federal de Paraná
# 29                             Universidade de São Paulo
# ...                                                  ...                ...
# 17545                            Fundação Getúlio Vargas          São Paulo
# 17546               Universidade Federal de Minas Gerais     Belo Horizonte
# 17547               Universidade Federal de Minas Gerais     Belo Horizonte
# 17548                            Fundação Getúlio Vargas          São Paulo
# 17549                            Fundação Getúlio Vargas          São Paulo
# 17550                          Universidade de São Paulo          São Paulo
# 17551            Universidade Federal da Grande Dourados           Dourados
# 17552            Universidade Federal da Grande Dourados           Dourados
# 17553            Universidade Federal da Grande Dourados           Dourados
# 17554            Universidade Federal da Grande Dourados           Dourados
# 17555            Universidade Federal da Grande Dourados           Dourados
# 17556        Universidade Estadual de Mato Grosso do Sul           Dourados
# 17557                     Universidade Estadual Paulista          Rio Claro
# 17558            Universidade Federal da Grande Dourados           Dourados
# 17559            Universidade Federal da Grande Dourados           Dourados
# 17560            Universidade Federal da Grande Dourados           Dourados
# 17561            Universidade Federal da Grande Dourados           Dourados
# 17562                   Taiyuan University of Technology            Taiyuan
# 17563                   Taiyuan University of Technology            Taiyuan
# 17564                   Taiyuan University of Technology            Taiyuan
# 17565                   Taiyuan University of Technology            Taiyuan
# 17566                   Taiyuan University of Technology            Taiyuan
# 17567                                University of Split              Split
# 17568                           Ruđer Bošković Institute             Zagreb
# 17569             Forensic Science Centre 'Ivan Vučetić'             Zagreb
# 17570             Forensic Science Centre 'Ivan Vučetić'             Zagreb
# 17571             Forensic Science Centre 'Ivan Vučetić'             Zagreb
# 17572             Forensic Science Centre 'Ivan Vučetić'             Zagreb
# 17573                               University of Zagreb             Zagreb
# 17574             Forensic Science Centre 'Ivan Vučetić'             Zagreb
#
# [17575 rows x 4 columns]

# %% [markdown]
# ### atualiza sexo em autores_selecionados

# %%
def get_sql_update_autor_nome_normal(autor_nome_completo,autor_nome_normal,scielo_id):
    sql = "update alacip.autores_selecionados as a set autor_nome_normal = " \
    +"'"+autor_nome_normal+"'" \
    +" WHERE artigo_scielo_id like " \
    +"'"+scielo_id+"'" \
    +" AND autor_nome_completo = " \
    +"'"+autor_nome_completo+"'" \
    +";"
    return sql

#sql = "update alacip.autores_selecionados as a set autor_nome_normal = '"+autor_nome_normal+"' WHERE CURRENT OF cursor;"
   

conn=pg.connect(connect_cmd)
cursor = conn.cursor()
cursor.execute('select artigo_scielo_id, autor_nome_completo, autor_nome from alacip.autores_selecionados;')
rows=cursor.fetchall()
for row in rows:
    scielo_id = row[0]
    autor_nome_completo = row[1]
    autor_nome = row[2]
    autor_nome_normal = normalizar_nome(autor_nome)
    if autor_nome != None:
        #print(get_sql_update_autor_nome_normal(autor_nome_completo,autor_nome_normal, scielo_id))
        #cursor.execute(sql)
        cursor.execute(get_sql_update_autor_nome_normal(autor_nome_completo,autor_nome_normal, scielo_id))
        conn.commit()
print("OK")
# Out:
# OK

# %%
query_update_sexo_M_em_todos_autores_selecionados = """
update alacip.autores_selecionados as a
    set autor_sexo = '#NONE';
    
update alacip.autores_selecionados as a
    set autor_sexo = 'M'
from alacip.nomes as n
    where upper(trim(n.nome_normal)) like upper(trim(split_part(a.autor_nome_normal, ' ', 1)))
    and n.sexo like 'M';
"""

query_update_sexo_F_em_autores_selecionados = """
update alacip.autores_selecionados as a
    set autor_sexo = 'F'
from alacip.nomes as n
    where upper(trim(n.nome_normal)) like upper(trim(split_part(a.autor_nome_normal, ' ', 1)))
    and n.sexo like 'F'
"""

query_update_sexo_X_em_autores_F_selecionados = """
update alacip.autores_selecionados as a
    set autor_sexo = 'X'
from alacip.nomes as n
    where upper(trim(n.nome_normal)) like upper(trim(split_part(a.autor_nome_normal, ' ', 1)))
    and n.sexo like 'M'
    and a.autor_sexo like 'F'
"""

query_update_sexo_X_em_autores_M_selecionados = """
update alacip.autores_selecionados as a
    set autor_sexo = 'X'
from alacip.nomes as n
    where upper(trim(n.nome_normal)) like upper(trim(split_part(a.autor_nome_normal, ' ', 1)))
    and n.sexo like 'F'
    and a.autor_sexo like 'M'
"""
# %sql {query_update_sexo_M_em_todos_autores_selecionados}

# %sql {query_update_sexo_F_em_autores_selecionados}

# %sql {query_update_sexo_X_em_autores_F_selecionados}

# %sql {query_update_sexo_X_em_autores_M_selecionados}
# Out:
# 15830 rows affected.
# 7679 rows affected.
# 4831 rows affected.
# 60 rows affected.
# 0 rows affected.
# []

# %%
import re
def normalizar_nome(nome):
    if nome != None:
        nome1 = nome.upper()
        nome2 = nome1.replace('Y','I')
        nome3 = nome2.replace('LL','L')
        n0 = nome3
        n1=re.sub('[Á|á|À|à|Â|â|Ã|ã|Ä|ä]','A',n0)
        n2=re.sub('[É|é|È|è|Ê|ê|Ẽ|ẽ|Ë|ë]','E',n1)
        n3=re.sub('[Í|í|Ì|ì|Î|î|Ĩ|ĩ|Ï|ï]','I',n2)
        n4=re.sub('[Ó|ó|Ò|ò|Ô|ô|Õ|õ|Ö|ö]','O',n3)
        n5=re.sub('[Ú|ú|Ù|ù|Û|û|Ũ|ũ|Ü|ü]','U',n4)
        n6=re.sub('[Ý|ý|Ỳ|ỳ|Ŷ|ŷ|Ỹ|ỹ|Ÿ|ÿ]','I',n5)
        n7=re.sub('[Ç|ç]','C',n6)
        n8=n7.replace('W','V')
        n9=n8.replace('LL','L')
        n10=n9.replace('TT','T')
        n11=n10.replace('AA','A')
        n12=n11.replace('MM','M')
        n13=n12.replace('NN','N')
        n14=n13.replace('RR','R')
        n15=n14.replace('SS','S')
        n16=n15.replace('BB','B')
        n17=n16.replace('EE','E')
        n18=n17.replace('DD','D')
        n19=n18.replace('HH','H')
        return re.sub('[\s+]', '', n19)
    else:
        return nome
