# %%
local_dir = '/home/neilor/scielo_db/dados'
xml_dir = '/home/neilor/scielo_db/dados/artigos_xml'
connect_cmd = "dbname='scielo_db' user='neilor' host='localhost' password='n1f2c3n1'"
# %load_ext sql
# %sql postgresql://neilor:n1f2c3n1@/scielo_db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: neilor@scielo_db'

# %%
import wgetter
import time
import os
import pandas as pd
import psycopg2 as pg
from pathlib import Path
from lxml import etree
from xml.etree.ElementTree import ParseError

# %%
query_create_table_xml_dados = """
drop table if exists alacip.xml_dados;
create table alacip.xml_dados
(
    scielo_id varchar,
    titulo text,
    resumo text,
    palavra_chave1 varchar,
    palavra_chave2 varchar,
    palavra_chave3 varchar,
    palavra_chave4 varchar,
    palavra_chave5 varchar,
    empirico varchar,
    tem_tabela varchar,
    tem_quadro varchar,
    tem_grafico varchar,
    tem_diagrama varchar,
    tem_figura varchar,
    abstract text,
    key_word1 varchar,
    key_word2 varchar,
    key_word3 varchar,
    key_word4 varchar,
    key_word5 varchar,
    texto text
);

CREATE INDEX texto_idx ON alacip.xml_dados USING GIN (to_tsvector('portuguese', texto));
"""

# %sql {query_create_table_xml_dados}
# Out:
# Done.
# Done.
# (psycopg2.ProgrammingError) relation "texto_idx" already exists
#  [SQL: "CREATE INDEX texto_idx ON alacip.xml_referencias USING GIN (to_tsvector('portuguese', texto));"]

# %%
url_xml = 'file:///home/neilor/scielo_db/dados/artigos_xml/S1415-47571998000100002.xml'
#url_xml = 'file:///home/neilor/scielo_db/dados/artigos_xml/S0104-62762016000100028.xml'
tree = etree.parse(url_xml)

def get_title(tree):
    r=tree.xpath('/article/front/article-meta/title-group/article-title')
    if r == []:
        return ''
    else:
        return r[0].text

def get_resumo(tree):
    r=tree.xpath('/article/front/article-meta/abstract[@xml:lang="pt"]')
    if r == []:
        return ''
    else:
        return(r[0][0].text)

def get_abstract(tree):
    r=tree.xpath('/article/front/article-meta/abstract[@xml:lang="en"]')
    if r == []:
        return ''
    else:
        return(r[0][0].text)

def get_palavras_chave(tree):
    r=tree.xpath('/article/front/article-meta/kwd-group/kwd[@lng="pt"]') 
    ke = []
    if r == []:
        return []
    else:
        for k in r:
            ke.append(k.text)
        return ke
    
def get_key_words(tree):
    r=tree.xpath('/article/front/article-meta/kwd-group/kwd[@lng="en"]') 
    ke = []
    if r == []:
        return []
    else:
        for k in r:
            ke.append(k.text)
        return ke

def get_autores(tree):
    n=tree.xpath('/article/front/article-meta/contrib-group/contrib[@contrib-type="author"]/name')
    nomes = []
    for i in n:
        nome = [i[0].text]+[i[1].text]
        nomes.append(nome)
    return nomes




def get_referencias_journal(tree):     
    print('========== ref ==================')
    r=tree.xpath('/article/back/ref-list/ref/nlm-citation[@citation-type="journal"]/*')
    nomes = []
    for i in r:
        print(i.text)
        #nome = [i[0].text]+[i[1].text]
        #nomes.append(nome)
    return nomes




def get_referencias_nomes(tree):     
    print('========== ref ==================')
    r=tree.xpath('/article/back/ref-list/ref/nlm-citation/person-group/name')
    nomes = []
    for i in r:
        nome = [i[0].text]+[i[1].text]
        nomes.append(nome)
    return nomes

def get_referencias_source(tree):     
    print('========== ref ==================')
    r=tree.xpath('/article/back/ref-list/ref/nlm-citation/source')
    fontes = []
    for i in r:
        fontes.append(i.text)
    return fontes

def get_book_autores(tree):
    n=tree.xpath('/article/back/ref-list/ref/nlm-citation[@citation-type="book"]/person-group[@person-group-type="author"]/name')
    nomes = []
    for i in n:
        nome = [i[0].text]+[i[1].text]
        nomes.append(nome)
    return nomes

def get_referencias(tree):     
    print('========== ref ==================')
    r=tree.xpath('/article/back/ref-list/ref/nlm-citation')
    fontes = []
    print(len(r))
    for i in r:
        citation_type = i.attrib['citation-type']
        if citation_type == 'book':
            autor = i[0]
        
        fonte=i.attrib['citation-type'],i[1].text
        fontes.append(fonte)
    return fontes

def get_texto(tree):     
    r=tree.xpath('/article/body')
    texto=''
    for b in r:
        if b.text != None:
            texto=texto+b.text
    return texto

#print(get_referencias_journal(tree))

# %%
#url_xml = 'file:///home/neilor/scielo_db/dados/artigos_xml/S1415-47572009000100001.xml'
url_xml = 'file:///home/neilor/scielo_db/dados/artigos_xml/S0104-62762016000100028.xml'

os.chdir(xml_dir)

import string as str

def sql_palavras_chave(palavras):
    n = len(palavras)
    pch = ["''","''","''","''","''"]
    for i in range(0,5):
        if i<n:
            palavra = palavras[i]
            palavra = palavra.replace("'", "''")
            pch[i]=("'"+palavra+"'")
    return (",".join(pch))

def sql_key_words(palavras):
    n = len(palavras)
    pch = ["''","''","''","''","''"]
    for i in range(0,5):
        if i<n:
            palavra = palavras[i]
            palavra = palavra.replace("'", "''")
            pch[i]=("'"+palavra+"'")
    return (",".join(pch))


def query_insert_dados_artigo_xml(scielo_id,arq_xml):
    try:
        tree = etree.parse(arq_xml)
        titulo = get_title(tree)
        titulo = titulo.replace("'", "''")
        
        resumo = get_resumo(tree)
        resumo = resumo.replace("'", "''")
        
        abstract = get_abstract(tree)
        abstract = abstract.replace("'", "''")
        #print(abstract)
        palavras_chave = get_palavras_chave(tree)
        #print(palavras_chave)
        palavras = sql_palavras_chave(palavras_chave)
        #print(palavras)
        
        key_words = get_key_words(tree)
        #print(key_words)
        words = sql_key_words(key_words)
        #print(words)
        
        values = "'"+scielo_id+"'"+",'"+titulo+"'"+",'"+resumo+"'"+","+palavras+",'"+abstract+"'"+","+words
        #print(values)
        sql = "insert into alacip.xml_dados  \
        (scielo_id,titulo,resumo,\
        palavra_chave1,palavra_chave2,palavra_chave3,palavra_chave4,palavra_chave5, \
        abstract,key_word1,key_word2,key_word3,key_word4,key_word5) values ("+values+");"

    except (etree.XMLSyntaxError, etree.ParseError):
        sql = "insert into alacip.xml_dados values ("+"'"+scielo_id+"','XML Invalido','','','');"
    return sql

#sql_palavras_chave(['a','b','c','d','e','f'])

#sql_palavras_chave(palavras_chave)



sql_publishing_id_scielo = "select scielo_id from alacip.artigos_selecionados"

conn = pg.connect("dbname='scielo_db' user='neilor' host='localhost' password='n1f2c3n1'")
df = pd.read_sql_query(sql_publishing_id_scielo, conn)

for scielo_id in df['scielo_id']:
    xml_file = xml_dir+'/'+scielo_id +'.xml'
    file_path = Path(xml_file)
    #print(scielo_id)
    query = query_insert_dados_artigo_xml(scielo_id,xml_file)
    #print(values)
    #rint(query)
    with conn:
        with conn.cursor() as curs:
            curs.execute(query)
    
conn.close()
print("OK")
# Out:
# OK

# %%
os.chdir(xml_dir)
  

def query_update_xml_texto(scielo_id,arq_xml):
    try:
        #print(scielo_id)
        tree = etree.parse(arq_xml)
        texto = get_texto(tree)
        texto = texto.replace("'", "''")
        sql =  "update alacip.xml_dados set texto = '"+texto+"' where scielo_id like '"+scielo_id+"';"
    except (etree.XMLSyntaxError, etree.ParseError):
        sql =  "update alacip.xml_dados set texto = 'XML Invalido'"+" where scielo_id like '"+scielo_id+"';"
    return sql 

sql_publishing_id_scielo = "select scielo_id from alacip.artigos_selecionados"

conn = pg.connect("dbname='scielo_db' user='neilor' host='localhost' password='n1f2c3n1'")
df = pd.read_sql_query(sql_publishing_id_scielo, conn)

for scielo_id in df['scielo_id']:
    xml_file = xml_dir+'/'+scielo_id +'.xml'
    file_path = Path(xml_file)
    query = query_update_xml_texto(scielo_id,xml_file)
    with conn:
        with conn.cursor() as curs:
            curs.execute(query)
    
conn.close()
print("OK")
# Out:
# OK

# %%
query_update_tem_elemento_empirico = """
update alacip.xml_dados
set tem_tabela = '0',
    tem_quadro = '0',
    tem_grafico = '0',
    tem_diagrama = '0',
    tem_figura = '0',
    empirico = '0'
;

update alacip.xml_dados
set tem_tabela = '1'
WHERE to_tsvector('portuguese', texto) @@ to_tsquery('portuguese', 'tabela')
;

update alacip.xml_dados
set tem_tabela = '1'
WHERE to_tsvector('english', texto) @@ to_tsquery('english', 'table')
;

update alacip.xml_dados
set tem_grafico = '1'
WHERE to_tsvector('portuguese', texto) @@ to_tsquery('portuguese', 'grafico' || 'grafo')
;

update alacip.xml_dados
set tem_grafico = '1'
WHERE to_tsvector('english', texto) @@ to_tsquery('english', 'graphic' || 'plot' || 'graph')
;

update alacip.xml_dados
set tem_quadro = '1'
WHERE to_tsvector('portuguese', texto) @@ to_tsquery('portuguese', 'quadro')
;

update alacip.xml_dados
set tem_diagrama = '1'
WHERE to_tsvector('portuguese', texto) @@ to_tsquery('portuguese', 'diagrama')
;

update alacip.xml_dados
set tem_diagrama = '1'
WHERE to_tsvector('english', texto) @@ to_tsquery('english', 'diagram' || 'chart' )
;

update alacip.xml_dados
set tem_figura = '1'
WHERE to_tsvector('portuguese', texto) @@ to_tsquery('portuguese', 'figura')
;

update alacip.xml_dados
set empirico = '1' 
where tem_tabela = '1' or tem_quadro = '1' or tem_diagrama = '1' or tem_figura = '1'
;

"""

conn = pg.connect("dbname='scielo_db' user='neilor' host='localhost' password='n1f2c3n1'")
with conn:
    with conn.cursor() as curs:
        curs.execute(query_update_tem_elemento_empirico)
        conn.commit()
# Out:
# 1

# %%
#url_xml = 'file:///home/neilor/scielo_db/dados/artigos_xml/S0011-52581996000300001.xml'
url_xml = 'file:///home/neilor/scielo_db/dados/artigos_xml/S0104-62762016000100028.xml'
tree = etree.parse(url_xml)


def get_citacoes_de_livro(tree):
    books=tree.xpath('/article/back/ref-list/ref/nlm-citation[@citation-type="book"]/*')
    for b in books:
        scielo_id = ''
        livro=''
                        
        #print(b.tag,b.text)
        if b.tag=='source':
            print('livro:',b.text)
        elif b.tag == 'person-group' and b.attrib['person-group-type']=='author':
            print('autor')
            for p in b[0]:
                print(p.tag,p.text)
        elif b.tag == 'person-group' and b.attrib['person-group-type']=='editor':
            print('editor')
            for p in b[0]:
                print(p.tag,p.text)
        elif b.tag=='source':
            print('fonte:',b.text)
        elif b.tag=='article-title':
            print('artigo_titulo',b.text)


get_citacoes_de_livro(tree)
# Out:
# autor
# surname Batagelj
# given-names V.
# artigo_titulo Large-scale network analysis
# editor
# surname Scott
# given-names J.
# livro: The Sage Handbook of Social Network Analysis
# autor
# surname Bourdoukan
# given-names A. Y.
# livro: "O bolso e a urna: financiamento político em perspectiva comparada"
# autor
# surname Costa
# given-names L. D.
# artigo_titulo Profissionalização ou popularização da classe política brasileira? Um perfil dos senadores da República
# editor
# surname Marenco dos Santos
# given-names A.
# livro: Os eleitos: representações e carreiras políticas em democracias
# autor
# surname Degenne
# given-names A.
# livro: Introducing social networks
# autor
# surname Figueiredo Filho
# given-names D. B.
# livro: "O elo corporativo? Grupos de interesse, financiamento de campanha e regulação eleitoral"
# autor
# surname Lima
# given-names S. M. P.
# livro: Prestação de contas e financiamento de campanhas eleitorais
# autor
# surname Lodoño;
# given-names J. F.
# artigo_titulo Latin America
# editor
# surname Falguera
# given-names E.
# livro: Funding of political parties and election campaigns: a handbook on political finance
# autor
# surname Newman
# given-names M. E. J.
# livro: Networks: an introduction
# autor
# surname Ohman
# given-names M.
# artigo_titulo Introduction to political finance
# editor
# surname Falguera
# given-names E.
# livro: Funding of political parties and election campaigns: a handbook on political finance
# autor
# surname Sawicki
# given-names F.
# artigo_titulo Por uma sociologia dos meios e das redes partidárias
# editor
# surname Marenco dos Santos
# given-names A.
# livro: Os eleitos: representações e carreiras políticas em democracias
# autor
# surname Schlickmann
# given-names D. G.
# livro: Financiamento de campanhas eleitorais

# %%
sql_publishing_id_scielo = "select texto from alacip.xml_dados"

conn = pg.connect("dbname='scielo_db' user='neilor' host='localhost' password='n1f2c3n1'")
df = pd.read_sql_query(sql_publishing_id_scielo, conn)
conn.close()

df
# Out:
#                                                   texto
# 0      <p><b>Resultados Experimentais, Problemas Con...
# 1      <p align="right"><font face="Verdana" size="2...
# 2      <p align="center"><b><font size=5>Choice of c...
# 3                                          XML Invalido
# 4                                          XML Invalido
# 5
# 6
# 7      <p align="right"><font face="Verdana, Arial, ...
# 8                                          XML Invalido
# 9      <strong><font FACE="Arial" COLOR="#800000">  ...
# 10     <p align="right"><font face="Verdana, Arial, ...
# 11     <b>      <p ALIGN="left"><a name="home"></a><...
# 12     <b>      <p ALIGN="left"><a name="home"></a><...
# 13     <B>     <P ALIGN="LEFT"><font size="4">Econom...
# 14     <p align="right"><font face="Verdana, Arial, ...
# 15     <b>      <p ALIGN="left"><font size="4"><a na...
# 16     <b>      <p ALIGN="left"><a name="titulo"></a...
# 17     <b>      <p ALIGN="left"><font size="4">Traba...
# 18
# 19     <p><font size="4" face="Verdana, Arial, Helve...
# 20     <p align="left"><b><font face="Verdana" size=...
# 21     <p><font size="4" face="Verdana"><B>Atualidad...
# 22     <p><font size="4" face="Verdana"><B><a name="...
# 23     <p><font size="4" face="Verdana"><B>Multicult...
# 24                                         XML Invalido
# 25                                         XML Invalido
# 26     <p align="right"><font size="2" face="Verdana...
# 27     <p><font size="4" face="verdana"><b>Dormindo ...
# 28     <p><font size="4" face="verdana"><b>Weber e o...
# 29     <p><font size="4" face="verdana"><b><a name="...
# ...                                                 ...
# 7170   <p><font size="4" face="Verdana"><B><a name="...
# 7171   <p><font size="4" face="verdana"><b><a name="...
# 7172   <p><font size="4" face="Verdana"><b>A "securi...
# 7173   <p align="right"><font size="2" face="Verdana...
# 7174   <p align="right"><font face="Verdana, Arial, ...
# 7175   <p align="right"><font face="verdana" size="2...
# 7176   <p><font size="4" face="verdana"><b>Vinte ano...
# 7177   <p><font size="4" face="verdana"><b><a name="...
# 7178    <font size="4" face="Verdana"><b>Margens da ...
# 7179   <p ALIGN="RIGHT"><b><a name="top"></a><font s...
# 7180   <b>      <p align="RIGHT"><font size="4">FRAC...
# 7181   <p align="right"><font face="Verdana, Arial, ...
# 7182   <p align="right"><font face="Verdana, Arial, ...
# 7183   <p align="right"><font size="2" face="Verdana...
# 7184   <p align="right"><font size="2" face="Verdana...
# 7185   <p align="right"><font face="Verdana" size="2...
# 7186    <!----------------------SE&Ccedil;&Atilde;O-...
# 7187   <p><font size="4" face="verdana"><b>Intensida...
# 7188   <p><font face="Verdana, Arial, Helvetica, san...
# 7189   <p align="right"><font face="Verdana, Arial, ...
# 7190   <b>     <p align="RIGHT"><font size="4"><a na...
# 7191   <p align="right"><font size="2" face="Verdana...
# 7192   <p><b><font face="Verdana, Arial, Helvetica-N...
# 7193   <p><font face="Verdana, Arial, Helvetica, san...
# 7194   <p><font size="4" face="Verdana, Arial, Helve...
# 7195   <p><font size="4" face="Verdana, Arial, Helve...
# 7196   <font size="3" FACE="Candida">      <p align=...
# 7197   <p align="right"><font size="2" face="verdana...
# 7198   <p align="right"><font face="Verdana, Arial, ...
# 7199   <P><FONT face="Verdana, Arial, Helvetica, san...
#
# [7200 rows x 1 columns]
