# %%
local_dir = '/home/neilor/SCIELO_DADOS/dados'
xml_dir = '/home/neilor/SCIELO_DADOS/dados/artigos_xml'
connect_cmd = "dbname='scielo_db' user='neilor' host='localhost' password='n1f2c3n1'"
from sqlalchemy import create_engine
engine = create_engine('postgresql://neilor:n1f2c3n1@localhost:5432/scielo_db')
#%load_ext sql
#%sql postgresql://neilor:n1f2c3n1@/scielo_db

# %%
import time
import os
import pandas as pd
import psycopg2 as pg
from pathlib import Path
from lxml import etree
from xml.etree.ElementTree import ParseError

# %%
class Scielo_XML(object):

    def __init__(self, url_xml):
        self.tree = etree.parse(url_xml)
        self.scielo_id = self.tree.xpath('/article/front/article-meta/article-id')[0].text
        

    def get_title(self):
        t=self.tree.xpath('/article/front/article-meta/title-group/article-title')
        titulo = {}
        titulo['scielo_id'] = self.scielo_id
        if t == []:
            n= ''
        else:
            n= t[0].text
        titulo['title'] = n
        return titulo
    

    def get_abstract(self):
        a=self.tree.xpath('/article/front/article-meta/abstract[@xml:lang="pt"]')
        resumo={}
        resumo['scielo_id'] = self.scielo_id
        if a == []:
            r = ''
        else:
            r =(a[0][0].text)
        resumo['abstract'] = r
        return resumo

    def get_keywords(self):
        ks=self.tree.xpath('/article/front/article-meta/kwd-group/kwd[@lng="pt"]') 
        keywords = []
        if ks == []:
            return []
        else:
            for k in ks:
                keywords.append(k.text)
            return keywords
        

    def get_autores(self):
        autors=self.tree.xpath('/article/front/article-meta/contrib-group/contrib[@contrib-type="author"]/name')
        autores = []
        autor = {}
        sq = 1
        for a in autors:
            autor['scielo_id'] = self.scielo_id
            autor['seq'] = str(sq);
            autor['aff_id'] = 'Af'+str(sq);
            autor['surname'] = a[0].text;
            autor['given_names'] = a[1].text;
            autores.append(autor)
            sq=sq+1
            autor={}
        return autores
    
    
    def get_referencias(self):     
        refs=self.tree.xpath('/article/back/ref-list/ref')
        referencia = {}
        referencias = []
        for r in refs:
            referencia['scielo_id']=self.scielo_id
            referencia['ref_id'] = r.attrib['id']
            citation_type = r[0].attrib['citation-type']
            referencia['citation_type'] = citation_type
            if citation_type == 'journal':
                #citation_type = i.attrib['citation-type']
                referencia['article_title'] = r[0][1].text
                at = (r[0][1].attrib).values()
                referencia['article_lang'] = ''.join(at)
                referencia['source'] = r[0][2].text
                referencia['year'] = r[0][3].text
                referencia['volume'] = r[0][4].text
                referencia['page_range'] = r[0][5].text
                referencias.append(referencia)
                print(referencia)
                referencia={}
            elif citation_type == 'book':
                referencia['source'] = r[0][1].text
                referencia['year'] = r[0][2].text
                referencia['publisher_loc'] = r[0][3].text
                referencia['publisher_name'] = r[0][4].text
                referencias.append(referencia)
                referencia={}
        return referencias


    def get_referencia_autores(self):     
        refs=self.tree.xpath('/article/back/ref-list/ref')
        ref_autor = {}
        ref_autores = []
        for ref in refs:
            ref_autor['scielo_id']=self.scielo_id
            ref_autor['ref_id'] = ref.attrib['id']
            #citation_type = i[0].attrib['citation-type']
            #referencia_autor['citation_type'] = citation_type
            autores = ref[0][0]
            seq = 1
            for autor in autores:
                ref_autor['seq'] = str(seq)
                ref_autor['surname'] = autor[0].text
                ref_autor['given_names'] = autor[1].text
                ref_autores.append(ref_autor)
                seq=seq+1
                ref_autor={}
        return ref_autores


    def get_texto(self): 
        r=self.tree.xpath('/article/body')
        texto=''
        for b in r:
            if b.text != None:
                texto=texto+b.text
        return texto

# %%
from IPython.display import display, HTML

url_xml = 'file:///home/neilor/SCIELO_DADOS/dados/artigos_xml/S1415-47571998000100002.xml'
#url_xml = 'file:///home/neilor/SCIELO_DADOS/dados/artigos_xml/S0104-62762016000100028.xml'

xml = Scielo_XML(url_xml)
#print(xml.get_title())
#print(xml.get_abstract())
#print(xml.get_autores())
print(xml.get_referencia_autores())
#HTML(xml.get_texto())
print(xml.get_keywords())
# Out:
# [{'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B1', 'seq': '1', 'surname': 'Adzuma', 'given_names': 'K.'}, {'seq': '2', 'surname': 'Ogawa', 'given_names': 'T.'}, {'seq': '3', 'surname': 'Ogawa', 'given_names': 'H.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B2', 'seq': '1', 'surname': 'Alani', 'given_names': 'E.'}, {'seq': '2', 'surname': 'Thresher', 'given_names': 'R.'}, {'seq': '3', 'surname': 'Griffith', 'given_names': 'J.D.'}, {'seq': '4', 'surname': 'Kolodner', 'given_names': 'R.D.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B3', 'seq': '1', 'surname': 'Bishop', 'given_names': 'D.K.'}, {'seq': '2', 'surname': 'Park', 'given_names': 'D.'}, {'seq': '3', 'surname': 'Xu', 'given_names': 'L.'}, {'seq': '4', 'surname': 'Kleckner', 'given_names': 'N.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B4', 'seq': '1', 'surname': 'Brozmanová', 'given_names': 'J.'}, {'seq': '2', 'surname': 'Cernaková', 'given_names': 'L.'}, {'seq': '3', 'surname': 'Vlcková', 'given_names': 'V.'}, {'seq': '4', 'surname': 'Duraj', 'given_names': 'J.'}, {'seq': '5', 'surname': 'Fridrichová', 'given_names': 'I.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B5', 'seq': '1', 'surname': 'Cernaková', 'given_names': 'L.'}, {'seq': '2', 'surname': 'Fridrichová', 'given_names': 'I.'}, {'seq': '3', 'surname': 'Pir\x9ael', 'given_names': 'M.'}, {'seq': '4', 'surname': 'Kleibl', 'given_names': 'K.'}, {'seq': '5', 'surname': 'Duraj', 'given_names': 'J.'}, {'seq': '6', 'surname': 'Brozmanová', 'given_names': 'J.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B6', 'seq': '1', 'surname': 'Emery', 'given_names': 'H.S.'}, {'seq': '2', 'surname': 'Schild', 'given_names': 'D.'}, {'seq': '3', 'surname': 'Kellogg', 'given_names': 'E.'}, {'seq': '4', 'surname': 'Mortimer', 'given_names': 'R.K.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B7', 'seq': '1', 'surname': 'Fridrichová', 'given_names': 'I.'}, {'seq': '2', 'surname': 'Kovaøík', 'given_names': 'A.'}, {'seq': '3', 'surname': 'Rosskopfová', 'given_names': 'O.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B8', 'seq': '1', 'surname': 'Friedberg', 'given_names': 'E.C.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B9', 'seq': '1', 'surname': 'Game', 'given_names': 'J.C.'}, {'seq': '2', 'surname': 'Mortimer', 'given_names': 'R.K.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B10', 'seq': '1', 'surname': 'Harlow', 'given_names': 'E.'}, {'seq': '2', 'surname': 'Lane', 'given_names': 'D.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B11', 'seq': '1', 'surname': 'Hays', 'given_names': 'S.L.'}, {'seq': '2', 'surname': 'Firmenich', 'given_names': 'A.A.'}, {'seq': '3', 'surname': 'Berg', 'given_names': 'P.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B12', 'seq': '1', 'surname': 'Henriques', 'given_names': 'J.A.P.'}, {'seq': '2', 'surname': 'Moustacchi', 'given_names': 'E.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B13', 'seq': '1', 'surname': 'Johnson', 'given_names': 'L.B.'}, {'seq': '2', 'surname': 'Thyagarajan', 'given_names': 'B.'}, {'seq': '3', 'surname': 'Krueger', 'given_names': 'L.'}, {'seq': '4', 'surname': 'Hirsch', 'given_names': 'B.'}, {'seq': '5', 'surname': 'Campbell', 'given_names': 'C.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B14', 'seq': '1', 'surname': 'Kans', 'given_names': 'J.A.'}, {'seq': '2', 'surname': 'Mortimer', 'given_names': 'R.K.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B15', 'seq': '1', 'surname': 'Kowalczykowski', 'given_names': 'S.C.'}, {'seq': '2', 'surname': 'Dixon', 'given_names': 'D.A.'}, {'seq': '3', 'surname': 'Eggleston', 'given_names': 'A.K.'}, {'seq': '4', 'surname': 'Lauder', 'given_names': 'S.D.'}, {'seq': '5', 'surname': 'Rehrauer', 'given_names': 'W.M.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B16', 'seq': '1', 'surname': 'Lovett', 'given_names': 'S.T.'}, {'scielo_id': 'S1415-47571998000100002', 'ref_id': 'B17', 'seq': '1', 'surna ...
# []

# %%
# %matplotlib inline 

import numpy as np
from PIL import Image
from os import path
import matplotlib.pyplot as plt
import random

from wordcloud import WordCloud, STOPWORDS
import nltk
from bs4 import BeautifulSoup 
url_xml = 'file:///home/neilor/SCIELO_DADOS/dados/artigos_xml/S1415-47571998000100002.xml'
#url_xml = 'file:///home/neilor/SCIELO_DADOS/dados/artigos_xml/S0104-62762016000100028.xml'

xml = Scielo_XML(url_xml)

data = xml.get_texto()
soup = BeautifulSoup(data, 'html.parser')

text = soup.get_text()

wc = WordCloud(width=1600, height=800, max_words=100,  stopwords=STOPWORDS, margin=10,random_state=1).generate(text)
plt.figure( figsize=(20,10), facecolor='k')
plt.imshow(wc)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
from IPython.core.display import display, HTML
display(HTML('<h1>Hello, world!</h1>'))
